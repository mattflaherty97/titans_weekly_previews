# %% [markdown]
# # Week 1 @ Chicago
#
# The NFL season is finally here. It's been 7 months since the final game of the 2023 season and much has happened with the franchise.

# %%
# @hidden_cell
from IPython.display import Image
Image("C:/Users/19012/Documents/Titans_weekly_previews/visuals/week1_chi/DefenseOffense.png")
